# %%
# Use git clone
# !git clone https://github.com/ife-dolapo/IntroToAI2.git
# Out:
# Cloning into 'IntroToAI2'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# Navigate into the Cloned folder
# %cd IntroToAI2
# Out:
# /content/IntroToAI2

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# List drive contents
# !ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
# 'Assignment 10 - Introduction to Matplotlib - Part 1.ipynb'
# 'Assignment 10 - Python for Data Analytics Basics.ipynb'
# ' Assignment 11 - Data Quality Dimensions.ipynb'
# 'Assignment 11 - Introduction to Matplotlib - Part 2.ipynb'
# 'Assignment 11 - Supervised Machine Learning with Python.ipynb'
# 'Assignment 12 - Data Documentation.ipynb'
# 'Assignment 12 - Introduction to Seaborn - Part 1.ipynb'
# 'Assignment 12 - Unsupervised Machine Learning with Python.ipynb'
# 'Assignment 13 - Introduction to Seaborn - Part 2.ipynb'
# 'Assignment 13 - Natural Language Processing with Python.ipynb'
# 'Assignment 14 - Introduction to Data Visualization.ipynb'
# 'Assignment 14 - Introduction to Seaborn - Part 3.ipynb'
# 'Assignment 14 - Summary of Mathematics for ML Module.ipynb'
# 'Assignment 15 -  Introduction to Plotly - Part 1.ipynb'
# 'Assignment 15 - Introduction to Web Scraping.ipynb'
# 'Assignment 16 - Introduction to Plotly - Part 2.ipynb'
# ...

# %%
# %pwd
# Out:
# '/content/IntroToAI2'

# %%
# Navigate to working directory
# %cd /content/IntroToAI2
# Out:
# /content/IntroToAI2

# %%
# Creating a Target Folder in Drive (Optional)
# !mkdir -p /content/drive/MyDrive/ColabRepos

# %%
# Copy the Repo Folder (-r mean recursive- it copies all files and subfolders )
# !cp -r /content/IntroToAI2 /content/drive/MyDrive/ColabRepos/

# %%
# Verify the move
# !ls /content/drive/MyDrive/ColabRepos/IntroToAI2
# Out:
# README.md

# %%
# Navigate to the New location
# %cd /content/drive/MyDrive/ColabRepos/IntroToAI2
# Out:
# /content/drive/MyDrive/ColabRepos/IntroToAI2

# %% [markdown]
# **Steps to Upload a Colab Notebook to GitHub**
#
#
# *   Mount Google Drive (if notebook is saved there)
# *   Navigate to the working directory

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/ColabRepos/IntroToAI2/.git/

# %%
# Setting my Git identity
# !git config --global user.name "ife-dolapo"
# !git config --global user.email "ifedolapootiko@gmail.com"

# %%
# Connect to my GitHub Repo
# %cd /content/drive/MyDrive/ColabRepos/IntroToAI2
# Out:
# /content/drive/MyDrive/ColabRepos/IntroToAI2

# %%
# Moving my notebook into the GitHub Repo Folder
# !mv "/content/drive/MyDrive/Colab Notebooks/Steps to Clone a GitHub Repo in Colab.ipynb" "/content/drive/MyDrive/ColabRepos/IntroToAI2"

# %%
# Add the Notebook
# !git add "Steps to Clone a GitHub Repo in Colab.ipynb"
# Out:
# fatal: pathspec 'Steps to Clone a GitHub Repo in Colab.ipynb' did not match any files
